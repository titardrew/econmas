# %%
import pickle

# %%
from simulation.data import get_last_sim_data

# %%
dc = get_last_sim_data()

# %%
mons, price, w_st, ins, outs = tuple(dc)

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib notebook
from simulation import AgentType
import pandas as pd

# %%
s = pd.Series(price[AgentType.HARVESTER])

# %%
# s.rolling(window=5).mean().plot(label='Harv');
# plt.legend(loc='best')

# %%
pd.Series(price[AgentType.INDUSTRIAL_A]).rolling(window=5).mean().plot(label='Ind1')
pd.Series(price[AgentType.INDUSTRIAL_B]).rolling(window=5).mean().plot(label='Ind2')
plt.legend(loc='best');
# Out:
# <img src="data:image/png;base64,..." width="640">
